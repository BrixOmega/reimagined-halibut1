# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8



version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]


if colabconfig["server_version"] < "1.18.2":
    #en la segunda linea de este if puedes cambiar la version de java que quieres instalar, (openjdk-𝟠-jre- (En el 8 puedes cambiarlo si lo necesitas dependiendo del error que te salga))
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-8-jre-headless &>/dev/null') and print("OpenJDK 8 installed") or print("Failed to install OpenJDK 8.")
# Instalar OpenJDK 17 si la version de Minecraft es 1.17 o superior
else:
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-17-jre-headless &>/dev/null') and print("OpenJDK 17 installed") or print("Failed to install OpenJDK 17.")

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2d3RUPq74dRu8Q9B9DRjblMTb7o_2xLgZxy2tDXNrG3i5S9fG" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui
    
    
elif tunnel_service == "zerotier":
    # Instalar ZeroTier
    # !curl -s https://install.zerotier.com | sudo bash

    # Ingresar a tu red de ZeroTier
    zerotier_network_id = "YOUR_NETWORK_ID"  # Remplaza con tu id de red de ZeroTier
    # !sudo zerotier-cli join $zerotier_network_id

    # Esperar a que ZeroTier se una a la red
    import time
    time.sleep(120)  # Aumentalo si es neceasrio

    #Chequea el estado de ZeroTier
    # !sudo zerotier-cli status


print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.18.2":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    ops.json	       user_jvm_args.txt
# banned-players.json  forge.jar.log  patchouli_books    usercache.json
# bukkit.yml	     help.yml	    permissions.yml    usernamecache.json
# colabconfig.json     libraries	    plugins	       whitelist.json
# commands.yml	     logs	    run.bat	       world
# config		     mods	    run.sh	       xaerominimap-common.txt
# defaultconfigs	     mohist-config  server.properties  xaeroworldmap-common.txt
# eula.txt	     mohist.jar     spigot.yml
# Failed to install OpenJDK 17.
# Reading package lists...Usando ngrok
#
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   ca-certificates-java java-common libpcsclite1
# Suggested packages:
#   default-jre pcscd libnss-mdns fonts-dejavu-extra fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   ca-certificates-java java-common libpcsclite1 openjdk-17-jre-headless
# 0 upgraded, 4 newly installed, 0 to remove and 28 not upgraded.
# Need to get 43.7 MB of archives.
# After this operation, 193 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:13325
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.18.2-146, Java(21.0.2) 65.0
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# No update found, the latest version: (146) current version: (146)
# Checking libraries, please wait...
# DownloadSource: MOHIST
# Download percentage:
#    0% [                                                    ] 0/1 (0:00:00 / ?)
# All libraries are nice :)!===========================] 1/1 (0:00:00 / 0:00:00)
# [05:46:18 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914, nogui]
# [05:46:18 INFO]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [05:46:19 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2316!/ Service=ModLauncher Env=SERVER
# [05:46:20 INFO]: Found 11 dependencies adding them to mods collection
# [05:46:26 INFO]: Compatibility level set to JAVA_17
# [05:46:26 ERROR]: Mixin config mixins.cinderscapes-worldgen.json does not specify "minVersion" property
# [05:46:26 ERROR]: Mixin config mixins.cinderscapes-common.json does not specify "minVersion" property
# [05:46:26 INFO]: Successfully loaded Mixin Connector [tictim.paraglider.MixinConnector]
# [05:46:26 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [05:46:26 WARN]: Reference map 'nethersdelight.refmap.json' for nethersdelight.mixins.json could not be read. If this is a development environment you can ignore this message
# [05:46:26 WARN]: Reference map 'cristellib-common-refmap.json' for cristellib-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [05:46:26 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [05:46:28 INFO]: No config file detected. Creating one...
# [05:46:28 INFO]: Loading config for 'terrablender_compatibility': TRUE
# [05:46:28 INFO]: No config file detected. Creating one...
# [05:46:28 INFO]: Loading config for 'cursed_skylands': NONE
# [05:46:36 WARN]: @ModifyConstant conflict. Skipping repurposed_structures.mixins.json:structures.StructurePoolMixin->@ModifyConstant::repurposedstructures_increaseWeightLimitDev(I)I with priority 1000, already redirected by yungsapi.mixins.json:IncreaseStructureWeightLimitMixin->@ModifyConstant::yungsapi_increaseWeightLimit(I)I with priority 1000
# [05:46:38 WARN]: @ModifyVariable(@At("INVOKE")) Shift.BY=4 on infernal-expansion.mixins.json:common.MixinMultiNoiseBiomeSourcePreset::localvar$zbg000$IE_addNetherBiomes exceeds the maximum allowed value: 0. Increase the value of maxShiftBy to suppress this warning.
# [05:46:42 INFO]: Attempting to load the Modding Legacy supporters list from https://moddinglegacy.com/supporters-changelogs/supporters.txt
# [05:46:42 INFO]: Constructing common components for mutantmonsters:main
# [05:46:42 INFO]: Successfully loaded the Modding Legacy supporters list.
# [05:46:42 INFO]: Infernal Expansion: Sound Events Registered!
# [05:46:43 INFO]: Infernal Expansion: Blocks Registered!
# [05:46:43 INFO]: Infernal Expansion: Items Registered!
# [05:46:43 INFO]: Infernal Expansion: Effects Registered!
# [05:46:43 INFO]: Infernal Expansion: Potions Registered!
# [05:46:43 INFO]: Infernal Expansion: Entity Types Registered!
# [05:46:43 INFO]: Infernal Expansion: Painting Types Registered!
# [05:46:43 INFO]: Infernal Expansion: Tile Entity Types Registered!
# [05:46:43 INFO]: Infernal Expansion: Biomes Registered!
# [05:46:43 INFO]: Infernal Expansion: Loot Modifiers Registered!
# [05:46:43 INFO]: Infernal Expansion: Entity Classifications Registered!
# [05:46:43 INFO]: Initialize mod Library Ferret
# [05:46:43 INFO]: Initialized mod Library Ferret
# [05:46:43 INFO]: Here we go! Launching Dungeon Crawl 2.3.14...
# [05:46:43 INFO]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [05:46:43 INFO]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [05:46:43 INFO]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [05:46:43 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [05:46:43 INFO]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [05:46:43 INFO]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [05:46:43 INFO]: Terrablender detected
# [05:46:44 INFO]: Detected new forge version, registering events reflectively.
# [05:46:44 INFO]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [05:46:44 INFO]: MinecraftForge v40.2.17 Initialized
# [05:46:44 INFO]: EventDispatcherRegistry initialized
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.SpiralSpiresModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.PermafrostModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.NoMoreLavaPocketsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.NewStoneTypesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.NetherObsidianSpikesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.MonsterBoxModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.GlimmeringWealdModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.FairyRingsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.CorundumModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.ChorusVegetationModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.BlossomTreesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.BigStoneClustersModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.BigDungeonModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.world.module.AzaleaWoodModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.VillagersFollowEmeraldsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.VexesDieWithTheirMastersModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.UtilityRecipesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.SnowGolemPlayerHeadsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.SimpleHarvestModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.SignEditingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.ReplaceScaffoldingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.ReacharoundPlacingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.PoisonPotatoUsageModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.PigLittersModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.PatTheDogsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.NoteBlockMobSoundsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.MoreBannerLayersModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.LockRotationModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.HoeHarvestingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.GrabChickensModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.GlassShardModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.EnhancedLaddersModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.EmotesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.DragonScalesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.DoubleDoorOpeningModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.CompassesWorkEverywhereModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.CampfiresBoostElytraModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.BetterElytraRocketModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.AutomaticRecipeUnlockModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tweaks.module.ArmedArmorStandsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.TrowelModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.SlimeInABucketModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.SkullPikesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.SeedPouchModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.PickarangModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.PathfinderMapsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.ParrotEggsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.EndermoshMusicDiscModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.ColorRunesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.CameraModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.BundleRecipeModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.BottledCloudModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.BeaconRedirectionModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.AncientTomesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.AmbientDiscsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.tools.module.AbacusModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.WraithModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.ToretoiseModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.StonelingsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.ShibaModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.FrogsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.FoxhoundModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.ForgottenModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.mobs.module.CrabsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.QuickArmorSwappingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.ItemSharingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.InventorySortingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.HotbarChangerModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.ExpandedItemInteractionsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.EasyTransferingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.management.module.ChestsInBoatsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.ZombieVillagersOnNormalModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.SpawnerReplacerModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.OverlayShaderModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.NarratorReadoutModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.GameNerfsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.EnchantmentsBegoneModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.experimental.module.AdjustableChatModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.VariantAnimalTexturesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.UsesForCursesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.UsageTickerModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.SoulCandlesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.MicrocraftingHelperModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.ImprovedTooltipsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.GreenerGrassModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.ChestSearchingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.BackButtonKeybind
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.client.module.AutoWalkKeybindModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.WoodenPostsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.VerticalSlabsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.VerticalPlanksModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.VariantLaddersModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.VariantFurnacesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.VariantChestsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.VariantBookshelvesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.ThatchModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.SturdyStoneModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.StoolsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.SoulSandstoneModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.ShinglesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.ShearVinesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.RopeModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.OrientalPaletteModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.NetherBrickFenceGateModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.MoreStoneVariantsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.MorePottedPlantsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.MoreBrickTypesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.MidoriModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.LeafCarpetModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.IndustrialPaletteModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.HedgesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.GrateModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.GoldBarsModule
# [05:46:46 INFO]: Kotlin For Forge Enabled!
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.GlassItemFrameModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.FramedGlassModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.DuskboundBlocksModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.CompressedBlocksModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.building.module.CelebratoryLampsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.RedstoneRandomizerModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.PistonsMoveTileEntitiesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.ObsidianPlateModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.MetalButtonsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.JukeboxAutomationModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.IronRodModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.GravisandModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.FeedingTroughModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.EnderWatcherModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.DispensersPlaceBlocksModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.ChuteModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.content.automation.module.ChainsConnectBlocksModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.TotemOfHoldingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.TinyPotatoModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.PipesModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.MatrixEnchantingModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.MagnetsModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.CrateModule
# [05:46:46 INFO]: Found Quark module class vazkii.quark.addons.oddities.module.BackpackModule
# [05:46:46 INFO]: Dispatching Module Step CONSTRUCT
# [05:46:46 INFO]: Constructing common components for puzzleslib:main
# [05:46:47 INFO]: dumping Runtime Pack's assets and data
# [05:46:56 INFO]: HELLO from Register Block
# [05:46:56 INFO]: Dispatching Module Step REGISTER
# [05:46:57 INFO]: Dispatching Module Step POST_REGISTER
# [05:47:01 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `shulker_shell`, expected `supplementaries`. This could be a intended override, but in most cases indicates a broken mod.
# [05:47:03 INFO]: Potentially Dangerous alternative prefix `terraform` for name `boat`, expected `terraform_wood_api_v1`. This could be a intended override, but in most cases indicates a broken mod.
# [05:47:03 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [05:47:03 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `flowing_milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [05:47:04 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `piglin_brute_specific_sensor`, expected `bygonenether`. This could be a intended override, but in most cases indicates a broken mod.
# [05:47:05 WARN]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityLeafcutterAnt from class com.github.alexthe666.alexsmobs.entity.EntityDevilsHolePupfish
# [05:47:05 WARN]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityMantisShrimp from class com.github.alexthe666.alexsmobs.entity.EntitySkelewag
# [05:47:05 WARN]: defineId called for: class org.infernalstudios.infernalexp.entities.ShroomloinEntity from class org.infernalstudios.infernalexp.entities.WarpbeetleEntity
# [05:47:06 INFO]: Loading Config: blue_skies-common.toml
# [05:47:06 INFO]: Loading Config: blue_skies-common.toml
# [05:47:06 INFO]: Loading common config for mutantmonsters
# [05:47:06 INFO]: Reloading common config for mutantmonsters
# [05:47:06 INFO]: Reloading common config for mutantmonsters
# [05:47:06 INFO]: [Structure Gel] Registering data for structure_gel:biome_dictionary
# [05:47:06 INFO]: [Structure Gel] Registering data for structure_gel:loot_table_alias
# [05:47:06 INFO]: [Structure Gel] Registering data for structure_gel:data_handler_type
# [05:47:06 INFO]: [Structure Gel] Registering data for structure_gel:dynamic_spawner
# [05:47:06 INFO]: [Structure Gel] Attempting to register unregistered biomes to the biome dictionary. This can be disabled via config
# [05:47:06 INFO]: [Structure Gel] Registered byg:temperate_grove to [structure_gel:plains, structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:amethyst_rainforest to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:mountain_steppe to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:blooming_valley to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:sierra_badlands to [structure_gel:plains, structure_gel:warm]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cloud_forest to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:windswept_spires to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:borealis_grove to [structure_gel:wooded, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:frozen_cliffs to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:frozen]
# [05:47:06 INFO]: [Structure Gel] Registered byg:cryptic_wastes to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:lush_stacks to [structure_gel:neutral_temp, structure_gel:ocean]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:shield_clearing to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:ethereal_islands to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:brushland to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:yosemite_cliffs to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/granite_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:tropical_jungle to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:tropical]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:blooming_plateau to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:bulbis_gardens to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/fungal_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave, structure_gel:fungal]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:wintry_lowlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:valley_clearing to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:lavender_forest to [structure_gel:flowery, structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:lush_valley to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:siberian_grove to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/desert_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:shield to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:viscal_isles to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:desert_canyon to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/andesite_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered byg:windswept_desert to [structure_gel:desert, structure_gel:hot, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:nightshade_forest to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:brimstone_caverns to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered byg:twilight_meadow to [structure_gel:wooded, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered byg:atacama_desert to [structure_gel:desert, structure_gel:hot, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:scarlet_mountains to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/tuff_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:rocky_mountains to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:hot_shrubland to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:skylands_spring to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:gravel_desert to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:magma_wastes to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/diorite_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:alpine_highlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:painted_mountains to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:araucaria_savanna to [structure_gel:dry, structure_gel:warm, structure_gel:savanna]
# [05:47:06 INFO]: [Structure Gel] Registered byg:rose_fields to [structure_gel:plains, structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:lavender_valley to [structure_gel:flowery, structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:amethyst_canyon to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/ice_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:alpha_islands_winter to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:rocky_shrubland to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:shulkren_forest to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:arisian_undergrowth to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:siberian_taiga to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/frostfire_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered byg:temperate_rainforest to [structure_gel:wooded, structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered byg:firecracker_shrubland to [structure_gel:desert, structure_gel:hot]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:rocky_jungle to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:mirage_isles to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:orchid_swamp to [structure_gel:flowery, structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:moonlight_valley to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:autumnal_taiga to [structure_gel:autumn_forest, structure_gel:spruce_forest, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered byg:white_mangrove_marshes to [structure_gel:neutral_temp, structure_gel:swamp]
# [05:47:06 INFO]: [Structure Gel] Registered byg:wailing_garth to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered byg:cardinal_tundra to [structure_gel:snowy, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered byg:cika_woods to [structure_gel:wooded, structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:temperate_highlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cold_shrubland to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered quark:glimmering_weald to [structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:basalt_cliffs to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:weeping_mire to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:savanna_badlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terrablender:deferred_placeholder to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:fractured_savanna to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:glacial_chasm to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:frosted_coniferous_forest to [structure_gel:snowy_spruce_forest, structure_gel:snowy, structure_gel:coniferous_forest]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:snowy_badlands to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:snowy]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:white_cliffs to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:yosemite_lowlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:ancient_sands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:coconino_meadow to [structure_gel:plains, structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:skylands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:desert_spires to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:skyris_vale to [structure_gel:mountain, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:alpine_grove to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:warm_river to [structure_gel:neutral_temp, structure_gel:river, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:autumnal_forest to [structure_gel:wooded, structure_gel:humid, structure_gel:autumn_forest, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/deep_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:volcanic_crater to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/crystal_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered byg:sythian_torrids to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered byg:dacite_ridges to [structure_gel:mountain, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:arid_highlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:snowy_maple_forest to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:snowy]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:skylands_winter to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:black_forest to [structure_gel:spruce_forest, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:moonlight_grove to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:forgotten_forest to [structure_gel:wooded, structure_gel:neutral_temp]
# [05:47:06 INFO]: [Structure Gel] Registered byg:windswept_dunes to [structure_gel:desert, structure_gel:hot, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:warped_mesa to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:wintry_forest to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:red_oasis to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:bryce_canyon to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:gravel_beach to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:beach]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:haze_mountain to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:sakura_valley to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:imparius_grove to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:emerald_peaks to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:steppe to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:skylands_summer to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:birch_taiga to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:snowy_shield to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:snowy]
# [05:47:06 INFO]: [Structure Gel] Registered byg:redwood_thicket to [structure_gel:wooded, structure_gel:humid, structure_gel:neutral_temp, structure_gel:redwood_forest]
# [05:47:06 INFO]: [Structure Gel] Registered byg:frosted_taiga to [structure_gel:snowy_spruce_forest, structure_gel:snowy]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:sakura_grove to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:savanna_slopes to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:white_mesa to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:stony_spires to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:red_rock_valley to [structure_gel:desert, structure_gel:warm]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:jungle_mountains to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:volcanic_peaks to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:yellowstone to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:windswept_beach to [structure_gel:neutral_temp, structure_gel:beach]
# [05:47:06 INFO]: [Structure Gel] Registered byg:subzero_hypogeal to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered byg:crimson_gardens to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:desert_oasis to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:skylands_autumn to [structure_gel:neutral_temp, structure_gel:autumn_forest, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:ice_marsh to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/infested_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered byg:canadian_shield to [structure_gel:snowy, structure_gel:snowy_mountain, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered byg:dacite_shore to [structure_gel:mountain, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:sandstone_valley to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/mantle_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered byg:fragment_forest to [structure_gel:wooded, structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:cave/thermal_caves to [structure_gel:neutral_temp, structure_gel:dry, structure_gel:cave]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:shrubland to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:howling_peaks to [structure_gel:cold]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:granite_cliffs to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:ashen_savanna to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:caldera to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered byg:quartz_desert to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [05:47:06 INFO]: [Structure Gel] Registered byg:basalt_barrera to [structure_gel:neutral_temp, structure_gel:beach]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:highlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:forested_highlands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: [Structure Gel] Registered terralith:alpha_islands to [structure_gel:neutral_temp, structure_gel:dry]
# [05:47:06 INFO]: Loading Module Redstone Randomizer
# [05:47:06 INFO]: Loading Module Pistons Move Tile Entities
# [05:47:06 INFO]: Loading Module Obsidian Plate
# [05:47:06 INFO]: Loading Module Metal Buttons
# [05:47:06 INFO]: Loading Module Jukebox Automation
# [05:47:06 INFO]: Loading Module Iron Rod
# [05:47:06 INFO]: Loading Module Gravisand
# [05:47:06 INFO]: Loading Module Feeding Trough
# [05:47:06 INFO]: Loading Module Ender Watcher
# [05:47:06 INFO]: Loading Module Dispensers Place Blocks
# [05:47:06 INFO]: Loading Module Chute
# [05:47:06 INFO]: Loading Module Chains Connect Blocks
# [05:47:06 INFO]: Loading Module Wooden Posts
# [05:47:06 INFO]: Loading Module Vertical Slabs
# [05:47:06 INFO]: Loading Module Vertical Planks
# [05:47:06 INFO]: Loading Module Variant Ladders
# [05:47:06 INFO]: Loading Module Variant Furnaces
# [05:47:06 INFO]: Loading Module Variant Chests
# [05:47:06 INFO]: Loading Module Variant Bookshelves
# [05:47:06 INFO]: Loading Module Thatch
# [05:47:06 INFO]: Loading Module Sturdy Stone
# [05:47:06 INFO]: Loading Module Stools
# [05:47:06 INFO]: Loading Module Soul Sandstone
# [05:47:06 INFO]: Loading Module Shingles
# [05:47:06 INFO]: Loading Module Shear Vines
# [05:47:06 INFO]: Loading Module Rope
# [05:47:06 INFO]: Loading Module Oriental Palette
# [05:47:06 INFO]: Loading Module Nether Brick Fence Gate
# [05:47:06 INFO]: Loading Module More Stone Variants
# [05:47:06 INFO]: Loading Module More Potted Plants
# [05:47:06 INFO]: Loading Module More Brick Types
# [05:47:06 INFO]: Loading Module Midori
# [05:47:06 INFO]: Loading Module Leaf Carpet
# [05:47:06 INFO]: Loading Module Industrial Palette
# [05:47:06 INFO]: Loading Module Hedges
# [05:47:06 INFO]: Loading Module Grate
# [05:47:06 INFO]: Loading Module Gold Bars
# [05:47:06 INFO]: Loading Module Glass Item Frame
# [05:47:06 INFO]: Loading Module Framed Glass
# [05:47:06 INFO]: Loading Module Duskbound Blocks
# [05:47:06 INFO]: Loading Module Compressed Blocks
# [05:47:06 INFO]: Loading Module Celebratory Lamps
# [05:47:06 INFO]: Loading Module Quick Armor Swapping
# [05:47:06 INFO]: Loading Module Item Sharing
# [05:47:06 INFO]: Loading Module Inventory Sorting
# [05:47:06 INFO]: Loading Module Hotbar Changer
# [05:47:06 INFO]: Loading Module Expanded Item Interactions
# [05:47:06 INFO]: Loading Module Easy Transfering
# [05:47:06 INFO]: Loading Module Chests In Boats
# [05:47:06 INFO]: Loading Module Trowel
# [05:47:06 INFO]: Loading Module Slime In A Bucket
# [05:47:06 INFO]: Loading Module Seed Pouch
# [05:47:06 INFO]: Loading Module Pickarang
# [05:47:06 INFO]: Loading Module Pathfinder Maps
# [05:47:06 INFO]: Loading Module Parrot Eggs
# [05:47:06 INFO]: Loading Module Endermosh Music Disc
# [05:47:06 INFO]: Loading Module Color Runes
# [05:47:06 INFO]: Loading Module Camera
# [05:47:06 INFO]: Loading Module Bundle Recipe
# [05:47:06 INFO]: Loading Module Bottled Cloud
# [05:47:06 INFO]: Loading Module Beacon Redirection
# [05:47:06 INFO]: Loading Module Ancient Tomes
# [05:47:06 INFO]: Loading Module Ambient Discs
# [05:47:06 INFO]: Loading Module Abacus
# [05:47:06 INFO]: Loading Module Villagers Follow Emeralds
# [05:47:06 INFO]: Loading Module Vexes Die With Their Masters
# [05:47:06 INFO]: Loading Module Utility Recipes
# [05:47:06 INFO]: Loading Module Snow Golem Player Heads
# [05:47:06 INFO]: Loading Module Simple Harvest
# [05:47:06 INFO]: Loading Module Sign Editing
# [05:47:06 INFO]: Loading Module Replace Scaffolding
# [05:47:06 INFO]: Loading Module Reacharound Placing
# [05:47:06 INFO]: Loading Module Poison Potato Usage
# [05:47:06 INFO]: Loading Module Pig Litters
# [05:47:06 INFO]: Loading Module Pat The Dogs
# [05:47:06 INFO]: Loading Module Note Block Mob Sounds
# [05:47:06 INFO]: Loading Module More Banner Layers
# [05:47:06 INFO]: Loading Module Lock Rotation
# [05:47:06 INFO]: Loading Module Hoe Harvesting
# [05:47:06 INFO]: Loading Module Grab Chickens
# [05:47:06 INFO]: Loading Module Glass Shard
# [05:47:06 INFO]: Loading Module Enhanced Ladders
# [05:47:06 INFO]: Loading Module Emotes
# [05:47:06 INFO]: Loading Module Dragon Scales
# [05:47:06 INFO]: Loading Module Double Door Opening
# [05:47:06 INFO]: Loading Module Compasses Work Everywhere
# [05:47:06 INFO]: Loading Module Campfires Boost Elytra
# [05:47:06 INFO]: Loading Module Better Elytra Rocket
# [05:47:06 INFO]: Loading Module Automatic Recipe Unlock
# [05:47:06 INFO]: Loading Module Armed Armor Stands
# [05:47:06 INFO]: Loading Module Skull Pikes
# [05:47:06 INFO]: Loading Module Spiral Spires
# [05:47:06 INFO]: Loading Module Permafrost
# [05:47:06 INFO]: Loading Module No More Lava Pockets
# [05:47:06 INFO]: Loading Module New Stone Types
# [05:47:06 INFO]: Loading Module Nether Obsidian Spikes
# [05:47:06 INFO]: Loading Module Monster Box
# [05:47:06 INFO]: Loading Module Glimmering Weald
# [05:47:06 INFO]: Loading Module Fairy Rings
# [05:47:06 INFO]: Loading Module Corundum
# [05:47:06 INFO]: Loading Module Chorus Vegetation
# [05:47:06 INFO]: Loading Module Blossom Trees
# [05:47:06 INFO]: Loading Module Big Stone Clusters
# [05:47:06 INFO]: Loading Module Big Dungeon
# [05:47:06 INFO]: Loading Module Azalea Wood
# [05:47:06 INFO]: Loading Module Wraith
# [05:47:06 INFO]: Loading Module Toretoise
# [05:47:06 INFO]: Loading Module Stonelings
# [05:47:06 INFO]: Loading Module Shiba
# [05:47:06 INFO]: Loading Module Frogs
# [05:47:06 INFO]: Loading Module Foxhound
# [05:47:06 INFO]: Loading Module Forgotten
# [05:47:06 INFO]: Loading Module Crabs
# [05:47:06 INFO]: Loading Module Variant Animal Textures
# [05:47:06 INFO]: Loading Module Uses For Curses
# [05:47:06 INFO]: Loading Module Usage Ticker
# [05:47:06 INFO]: Loading Module Soul Candles
# [05:47:06 INFO]: Loading Module Microcrafting Helper
# [05:47:06 INFO]: Loading Module Improved Tooltips
# [05:47:06 INFO]: Loading Module Greener Grass
# [05:47:06 INFO]: Loading Module Chest Searching
# [05:47:06 INFO]: Loading Module Back Button Keybind
# [05:47:06 INFO]: Loading Module Auto Walk Keybind
# [05:47:06 INFO]: Loading Module Zombie Villagers On Normal
# [05:47:06 INFO]: Loading Module Spawner Replacer
# [05:47:06 INFO]: Loading Module Overlay Shader
# [05:47:06 INFO]: Loading Module Narrator Readout
# [05:47:06 INFO]: Loading Module Game Nerfs
# [05:47:06 INFO]: Loading Module Enchantments Begone
# [05:47:06 INFO]: Loading Module Adjustable Chat
# [05:47:06 INFO]: Loading Module Totem Of Holding
# [05:47:06 INFO]: Loading Module Tiny Potato
# [05:47:06 INFO]: Loading Module Pipes
# ...
# [05:48:12 INFO]: Loaded 23 dynamic modifiers in 0.795674 ms
# [05:48:12 INFO]: Loaded 56 materials in 6.478269 ms
# [05:48:13 INFO]: Loaded 1 material tags for 20 materials in 227.19063 ms
# [05:48:13 INFO]: 196 stats loaded for 65 materials in 213.7066 ms
# [05:48:13 INFO]: 86 traits loaded for 65 materials in 203.31784 ms
# [05:48:13 INFO]: Loaded 33 tool definitions in 8.449387 ms
# [05:48:13 INFO]: Loaded 18 station slot layouts in 2.430986 ms
# [05:48:16 INFO]: Finished additional setup in 0 seconds
# [05:48:17 INFO]: Applied 0 biome modifications to 0 of 340 new biomes in 3.517 ms
# [05:48:17 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/nether-biomes.json5" was read.
# [05:48:17 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/end-biomes.json5" was read.
# [05:48:17 INFO]: Starting minecraft server version 1.18.2
# [05:48:17 INFO]: Loading properties
# [05:48:17 INFO]: Default game type: SURVIVAL
# [05:48:17 INFO]: Generating keypair
# [05:48:17 INFO]: Starting Minecraft server on *:25565
# [05:48:17 INFO]: Using epoll channel type
# [05:48:17 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [05:48:17 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [05:48:17 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [05:48:17 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [05:48:17 INFO]: This server is running Mohist version 1.18.2-146 (MC: 1.18.2) (Implementing API version 1.18.2-R0.1-SNAPSHOT, Forge version 40.2.17)
# [05:48:20 INFO]: Debug logging is enabled
# [05:48:20 INFO]: Server Ping Player Sample Count: 12
# [05:48:20 INFO]: Using 4 threads for Netty based IO
# [05:48:21 INFO]: Initialized TerraBlender biomes for level stem minecraft:overworld
# [05:48:21 INFO]: Preparing level "world"
# [05:48:23 INFO]: []
# [05:48:23 INFO]: [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [05:48:23 INFO]: Preparing start region for dimension minecraft:overworld
# [05:48:24 INFO]: Preparing spawn area: 0%
# [05:48:24 INFO]: Preparing spawn area: 0%
# [05:48:24 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:31 INFO]: Preparing spawn area: 0%
# [05:48:32 INFO]: Preparing spawn area: 0%
# [05:48:32 INFO]: Preparing spawn area: 9%
# [05:48:33 INFO]: Preparing spawn area: 24%
# [05:48:33 INFO]: Preparing spawn area: 45%
# [05:48:34 INFO]: Preparing spawn area: 51%
# [05:48:34 INFO]: Preparing spawn area: 88%
# [05:48:35 INFO]: Preparing spawn area: 93%
# [05:48:35 INFO]: Time elapsed: 12439 ms
# [05:48:35 INFO]: Preparing start region for dimension blue_skies:everdawn
# [05:48:36 INFO]: Preparing spawn area: 0%
# [05:48:36 INFO]: Preparing spawn area: 0%
# [05:48:38 INFO]: Preparing spawn area: 0%
# [05:48:38 INFO]: Preparing spawn area: 0%
# [05:48:38 INFO]: Preparing spawn area: 0%
# [05:48:38 INFO]: Preparing spawn area: 0%
# [05:48:39 INFO]: Preparing spawn area: 0%
# [05:48:39 INFO]: Preparing spawn area: 0%
# [05:48:40 INFO]: Preparing spawn area: 0%
# [05:48:41 INFO]: Preparing spawn area: 1%
# [05:48:41 INFO]: Preparing spawn area: 1%
# [05:48:41 INFO]: Preparing spawn area: 1%
# [05:48:42 INFO]: Preparing spawn area: 7%
# [05:48:43 INFO]: Preparing spawn area: 33%
# [05:48:43 INFO]: Preparing spawn area: 33%
# [05:48:43 INFO]: Preparing spawn area: 33%
# [05:48:43 INFO]: Preparing spawn area: 55%
# [05:48:44 INFO]: Preparing spawn area: 80%
# [05:48:44 INFO]: Preparing spawn area: 84%
# [05:48:45 INFO]: Preparing spawn area: 89%
# [05:48:45 INFO]: Preparing spawn area: 96%
# [05:48:46 INFO]: Time elapsed: 10288 ms
# [05:48:46 INFO]: Preparing start region for dimension minecraft:the_end
# [05:48:46 INFO]: Preparing spawn area: 0%
# [05:48:46 INFO]: Preparing spawn area: 0%
# [05:48:47 INFO]: Preparing spawn area: 3%
# [05:48:47 INFO]: Preparing spawn area: 34%
# [05:48:48 INFO]: Preparing spawn area: 85%
# [05:48:48 INFO]: Preparing spawn area: 94%
# [05:48:49 INFO]: Time elapsed: 2785 ms
# [05:48:49 INFO]: Preparing start region for dimension blue_skies:everbright
# [05:48:49 INFO]: Preparing spawn area: 0%
# [05:48:49 INFO]: Preparing spawn area: 0%
# [05:48:50 INFO]: Preparing spawn area: 0%
# [05:48:50 INFO]: Preparing spawn area: 0%
# [05:48:52 INFO]: Preparing spawn area: 0%
# [05:48:52 INFO]: Preparing spawn area: 0%
# [05:48:52 INFO]: Preparing spawn area: 0%
# [05:48:52 INFO]: Preparing spawn area: 9%
# [05:48:53 INFO]: Preparing spawn area: 32%
# [05:48:53 INFO]: Preparing spawn area: 54%
# [05:48:54 INFO]: Preparing spawn area: 77%
# [05:48:54 INFO]: Preparing spawn area: 84%
# [05:48:55 INFO]: Preparing spawn area: 86%
# [05:48:55 INFO]: Preparing spawn area: 89%
# [05:48:56 INFO]: Preparing spawn area: 94%
# [05:48:56 INFO]: Time elapsed: 7406 ms
# [05:48:56 INFO]: Preparing start region for dimension minecraft:the_nether
# [05:48:56 INFO]: Preparing spawn area: 0%
# [05:48:56 INFO]: Preparing spawn area: 0%
# [05:48:57 INFO]: Preparing spawn area: 0%
# [05:48:58 INFO]: Preparing spawn area: 0%
# [05:48:58 INFO]: Preparing spawn area: 0%
# [05:48:59 INFO]: Preparing spawn area: 1%
# [05:48:59 INFO]: Preparing spawn area: 1%
# [05:48:59 INFO]: Preparing spawn area: 52%
# [05:49:00 INFO]: Preparing spawn area: 75%
# [05:49:01 INFO]: Preparing spawn area: 82%
# [05:49:01 WARN]: Empty height range: [6 below top-6 above bottom]
# [05:49:01 INFO]: Preparing spawn area: 84%
# [05:49:01 INFO]: Preparing spawn area: 87%
# [05:49:02 INFO]: Preparing spawn area: 95%
# [05:49:02 INFO]: Preparing spawn area: 97%
# [05:49:03 INFO]: Time elapsed: 6798 ms
# [05:49:03 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [05:49:03 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/overworld_surface_rules.json5" was read.
# [05:49:03 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/end_surface_rules.json5" was read.
# [05:49:03 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/nether_surface_rules.json5" was read.
# [05:49:03 INFO]: Loading dimension "minecraft:the_nether" with biome source: "byg:nether".
# [05:49:03 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/overworld_surface_rules.json5" was read.
# [05:49:03 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/end_surface_rules.json5" was read.
# [05:49:03 INFO]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/nether_surface_rules.json5" was read.
# [05:49:03 INFO]: Loading dimension "minecraft:the_end" with biome source: "byg:end".
# [05:49:03 INFO]: Done (42.599s)! For help, type "help"
# [05:49:03 INFO]: Successfully initialized permission handler forge:default_handler
# [05:49:03 INFO]: HELLO from server starting
# [05:49:03 INFO]: {SPAWN_DRAGON_SKELETON_I_CF=true, HYDRA_CAVE_CF=true, SPAWN_SEA_SERPENT_CF=true, SPAWN_STYMPHALIAN_BIRD_CF=true, SPAWN_WANDERING_CYCLOPS_CF=true, PIXIE_VILLAGE_CF=true, SPAWN_DEATH_WORM_CF=true, FIRE_DRAGON_CAVE_CF=true, SIREN_ISLAND_CF=true, MYRMEX_HIVE_DESERT_CF=true, SPAWN_HIPPOCAMPUS_CF=true, FIRE_DRAGON_ROOST_CF=true, MYRMEX_HIVE_JUNGLE_CF=true, COPPER_ORE_CF=true, SILVER_ORE_CF=true, LIGHTNING_DRAGON_CAVE_CF=true, SPAWN_DRAGON_SKELETON_F_CF=true, AMETHYST_ORE_CF=true, SPAWN_DRAGON_SKELETON_L_CF=true, LIGHTNING_LILY_CF=true, ICE_DRAGON_CAVE_CF=true, SAPPHIRE_ORE_CF=true, LIGHTNING_DRAGON_ROOST_CF=true, CYCLOPS_CAVE_CF=true, FROST_LILY_CF=true, FIRE_LILY_CF=true, ICE_DRAGON_ROOST_CF=true}
# [05:49:03 INFO]: {TROLL_S=true, HIPPOGRYPH=true, AMPHITHERE=true, COCKATRICE=true, TROLL_M=true, DREAD_LICH=true, TROLL_F=true}
# [05:49:03 INFO]: Sending reload packet to clients
# [05:49:38 INFO]: UUID of player Brayanmatomipc is 13e7d098-664e-36e8-86f9-8aa7b8eeb3fb
# [05:49:44 INFO]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@5a8e94f8
# [05:49:44 INFO]: Sending ToolHandleTypeManager to Brayanmatomipc
# [05:49:44 INFO]: Sending SnowcapOvenFreezingManager to Brayanmatomipc
# [05:49:44 INFO]: Sending HorizoniteForgeFuelManager to Brayanmatomipc
# [05:49:44 INFO]: Sending AlchemyRecipeManager to Brayanmatomipc
# [05:49:44 INFO]: Sending JournalEntryManager to Brayanmatomipc
# [05:49:44 INFO]: Sending JournalSectionManager to Brayanmatomipc
# [05:49:44 INFO]: Sending JournalRequirementManager to Brayanmatomipc
# [05:49:44 INFO]: Syncing config to Brayanmatomipc (13e7d098-664e-36e8-86f9-8aa7b8eeb3fb)
# [05:49:44 INFO]: Brayanmatomipc[localhost/127.0.0.1:53018] logged in with entity id 831 at (-200.00252826353497, 68.0, 325.39889115810263)
# [05:52:14 INFO]: UUID of player Stellfront is a27dbd97-b502-3dfd-8a62-c6e01ab6a2e9
# [05:52:22 INFO]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@71666183
# [05:52:22 INFO]: Sending ToolHandleTypeManager to Stellfront
# [05:52:22 INFO]: Sending SnowcapOvenFreezingManager to Stellfront
# [05:52:22 INFO]: Sending HorizoniteForgeFuelManager to Stellfront
# [05:52:22 INFO]: Sending AlchemyRecipeManager to Stellfront
# [05:52:22 INFO]: Sending JournalEntryManager to Stellfront
# [05:52:22 INFO]: Sending JournalSectionManager to Stellfront
# [05:52:22 INFO]: Sending JournalRequirementManager to Stellfront
# [05:52:22 INFO]: Syncing config to Stellfront (a27dbd97-b502-3dfd-8a62-c6e01ab6a2e9)
# [05:52:22 INFO]: Stellfront[localhost/127.0.0.1:44324] logged in with entity id 1089 at (-452.89786281506395, 67.0, 302.9959411911026)
# [05:52:50 WARN]: Unhandled statistic: Stat{name=minecraft.custom:tombstone.undead_killed, formatter=net.minecraft.stats.StatFormatter$Lambda/0x00007f6fd4aa65f8@13d5ad7e}
# [05:52:50 INFO]: Brayanmatomipc has made the advancement [Monster Hunter]
# [05:53:36 INFO]: Brayanmatomipc has made the advancement [Stone Age]
# [05:54:20 WARN]: Unhandled statistic: Stat{name=minecraft.custom:tombstone.undead_killed, formatter=net.minecraft.stats.StatFormatter$Lambda/0x00007f6fd4aa65f8@13d5ad7e}
# [05:54:22 INFO]: <Stellfront> -476, 320
# [05:54:38 INFO]: <Brayanmatomipc> -265 374
# [05:55:01 INFO]: <Stellfront> xaero-waypoint:Shared Location:S:-474:68:303:9:false:0:Internal-overworld-waypoints
# [05:55:36 INFO]: Stellfront has made the advancement [Sweet Dreams]
# [05:56:09 WARN]: Unhandled statistic: Stat{name=minecraft.custom:tombstone.undead_killed, formatter=net.minecraft.stats.StatFormatter$Lambda/0x00007f6fd4aa65f8@13d5ad7e}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [05:56:43 INFO]: Brayanmatomipc has made the advancement [A Seedy Place]
# [05:57:04 INFO]: Stellfront has made the advancement [Getting an Upgrade]
# [05:59:45 INFO]: Stellfront has made the advancement [Monster Hunter]
# [06:03:55 INFO]: Stopping server
# [06:03:55 INFO]: Saving players
# [06:03:55 INFO]: Brayanmatomipc lost connection: Server closed
# [06:03:55 INFO]: Brayanmatomipc left the game.
# [06:03:55 INFO]: Stellfront lost connection: Server closed
# [06:03:55 INFO]: Stellfront left the game.
# [06:03:56 INFO]: Saving worlds
# >
# t=2024-03-03T06:04:03+0000 lvl=warn msg="failed to open private leg" id=a2994b6a4dc4 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [06:04:03 INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:overworld
# >
# t=2024-03-03T06:04:03+0000 lvl=warn msg="failed to open private leg" id=82fb0c8943f7 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:04:04+0000 lvl=warn msg="failed to open private leg" id=0c4272da45b7 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:04:04+0000 lvl=warn msg="failed to open private leg" id=8cbdcd1b7429 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:04:07+0000 lvl=warn msg="failed to open private leg" id=3a9f21c50873 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [06:04:58 INFO]: Saving chunks for level 'ServerLevel[world]'/blue_skies:everdawn
# [06:04:58 INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:the_end
# [06:04:58 INFO]: Saving chunks for level 'ServerLevel[world]'/blue_skies:everbright
# [06:04:58 INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:the_nether
# [06:04:58 INFO]: ThreadedAnvilChunkStorage (world): All chunks are saved
# [06:04:58 INFO]: ThreadedAnvilChunkStorage (everdawn): All chunks are saved
# [06:04:58 INFO]: ThreadedAnvilChunkStorage (DIM1): All chunks are saved
# [06:04:58 INFO]: ThreadedAnvilChunkStorage (everbright): All chunks are saved
# [06:04:58 INFO]: ThreadedAnvilChunkStorage (DIM-1): All chunks are saved
# [06:04:58 INFO]: ThreadedAnvilChunkStorage: All dimensions are saved
# >
# t=2024-03-03T06:05:01+0000 lvl=warn msg="failed to open private leg" id=d171e57e497a typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:02+0000 lvl=warn msg="failed to open private leg" id=6c15bffa7378 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:02+0000 lvl=warn msg="failed to open private leg" id=fd7266c57660 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:11+0000 lvl=warn msg="failed to open private leg" id=16967e1592d8 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:19+0000 lvl=warn msg="failed to open private leg" id=7e72586c7310 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:19+0000 lvl=warn msg="failed to open private leg" id=a93fef74a22f typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:20+0000 lvl=warn msg="failed to open private leg" id=7594d2531e16 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:05:24+0000 lvl=warn msg="failed to open private leg" id=3d49916fdab5 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-03T06:06:10+0000 lvl=warn msg="failed to open private leg" id=c87972e11c77 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-03T06:06:11+0000 lvl=warn msg="failed to open private leg" id=d2a221056a8b typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
